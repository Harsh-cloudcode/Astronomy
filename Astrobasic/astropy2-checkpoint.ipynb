# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
from astropy.io import fits

# %%
Object = fits.open('Untitled Folder\mips_24micron.fits')

# %%
Object

# %%
Object.info()
# Out:
# Filename: Untitled Folder\mips_24micron.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      18   (756, 396)   float64

# %%
Object[0]

# %%
Object[0].header
# Out:
# SIMPLE  =                    T
# BITPIX  =                  -64
# NAXIS   =                    2
# NAXIS1  =                  756
# NAXIS2  =                  396
# EXTEND  =                    T / FITS dataset may contain extensions
# COMMENT   FITS (Flexible Image Transport System) format is defined in 'Astronomy
# COMMENT   and Astrophysics', volume 376, page 359; bibcode: 2001A&A...376..359H
# CTYPE1  = 'RA---TAN'
# CTYPE2  = 'DEC--TAN'
# EQUINOX =                2000.
# CRVAL1  =        266.405019062
# CRVAL2  =        -28.936187042
# CDELT1  =         -0.002777776
# CDELT2  =          0.002777776
# CRPIX1  =             378.1875
# CRPIX2  =             198.1875
# CROTA2  =        328.599681201

# %%
img_data = Object[0].data

# %%
img_data
# Out:
# array([[22.76379395, 23.42649338, 23.9472724 , ..., 32.20745134,
#         32.76589372, 33.11872614],
#        [22.34547807, 22.68162212, 22.89341712, ..., 32.68974991,
#         33.13367496, 30.74516408],
#        [21.89944863, 22.01189703, 22.6158635 , ..., 32.2493688 ,
#         31.69833758, 29.00357254],
#        ...,
#        [20.96165085, 21.18307436, 21.47873281, ..., 17.82160318,
#         18.08227667, 17.79266705],
#        [20.07846599, 20.15343674, 20.32275144, ..., 17.2234756 ,
#         17.49986253, 17.72104177],
#        [19.99313862, 20.02355809, 19.840935  , ..., 17.85447458,
#         20.62017612, 17.68880369]])

# %%
# Out:
# Min: nan
# Max: nan
# Mean: nan
# Stdev: nan

# %%
img_data.shape
# Out:
# (396, 756)

# %%
img_data.dtype.name
# Out:
# 'float64'

# %%
plt.imshow(img_data)

# %%
M42u = fits.open('data\\2MASS_h.fits')
M42i = fits.open('data\\2MASS_j.fits')
M42g = fits.open('data\\2MASS_k.fits')

# %%
from astropy.visualization import make_lupton_rgb

# %%
g = M42g[0].data
r = M42i[0].data
b = M42u[0].data

# %%
rgb_default = make_lupton_rgb(r, g, b, stretch=1.5,Q=10)



plt.imshow(rgb_default, origin='lower')
plt.savefig("rgbM42.jpg")

# %%
gc = aplpy.FITSFigure('data\\2MASS_k.fits') # loading the image as an aplpy object
gc.show_grayscale() #displaying the image..
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 gc = aplpy.FITSFigure('data\\2MASS_k.fits') # loading the image as an aplpy object
#       2 gc.show_grayscale()
#
# NameError: name 'aplpy' is not defined

# %%
pip install aplpy

# %%
gc = aplpy.FITSFigure('data\\2MASS_k.fits') # loading the image as an aplpy object
gc.show_grayscale() #displaying the image..
